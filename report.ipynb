# %%
from performance import *

# %% [markdown]
# # Run Performance
#
# Source code: https://github.com/kai-trading-bot/pair/blob/main/performance.py#L22

# %%
# %matplotlib notebook
Performance.trade_report()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <style type="text/css">
# #T_bcdc6_row0_col0, #T_bcdc6_row1_col0, #T_bcdc6_row2_col3, #T_bcdc6_row3_col3, #T_bcdc6_row4_col0, #T_bcdc6_row5_col0, #T_bcdc6_row6_col0, #T_bcdc6_row7_col0, #T_bcdc6_row8_col0, #T_bcdc6_row9_col0, #T_bcdc6_row10_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_bcdc6_row0_col1, #T_bcdc6_row1_col3, #T_bcdc6_row2_col0, #T_bcdc6_row3_col0, #T_bcdc6_row4_col1, #T_bcdc6_row5_col1, #T_bcdc6_row6_col2, #T_bcdc6_row7_col1, #T_bcdc6_row8_col1, #T_bcdc6_row9_col1, #T_bcdc6_row10_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bcdc6_row0_col2 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_bcdc6_row0_col3 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_bcdc6_row1_col1 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_bcdc6_row1_col2, #T_bcdc6_row5_col2 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_bcdc6_row2_col1 {
# ...
